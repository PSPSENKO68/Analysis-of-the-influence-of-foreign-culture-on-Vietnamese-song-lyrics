# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install groq pandas
# Out:
# Collecting groq
#   Downloading groq-1.0.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading groq-1.0.0-py3-none-any.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 4.6 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-1.0.0

# %%
import pandas as pd
import json
import time
import os
import csv
from groq import Groq
from dotenv import load_dotenv

load_dotenv()

# ================= CẤU HÌNH =================
GROQ_API_KEY = os.getenv("GROQ_API_KEY")

if not GROQ_API_KEY:
    raise ValueError("❌ GROQ_API_KEY not found. Check your .env file")

INPUT_FILE_PATH = "/content/drive/MyDrive/Word_label_LLM/final_dataset_cleaned_v3_new_part3.csv"
OUTPUT_FILE_PATH = "/content/drive/MyDrive/Word_label_LLM/output_labeling_part3.csv"


# ================= MODEL POOL =================
MODEL_LIST = [
    "llama-3.1-8b-instant",
    "llama-3.3-70b-versatile",
    "openai/gpt-oss-120b",
    "openai/gpt-oss-20b",
    "meta-llama/llama-4-maverick-17b-128e-instruct",
    "meta-llama/llama-4-scout-17b-16e-instruct",
    "qwen/qwen3-32b"
]

CURRENT_MODEL_INDEX = 0
CURRENT_MODEL = MODEL_LIST[CURRENT_MODEL_INDEX]
# ============================================

client = Groq(api_key=GROQ_API_KEY)

def switch_model():
    """Chuyển sang model tiếp theo khi hết token"""
    global CURRENT_MODEL_INDEX, CURRENT_MODEL
    CURRENT_MODEL_INDEX = (CURRENT_MODEL_INDEX + 1) % len(MODEL_LIST)
    CURRENT_MODEL = MODEL_LIST[CURRENT_MODEL_INDEX]
    print(f"\n[⚠️ SWITCH MODEL] → {CURRENT_MODEL}")

def ask_llama_label(lyrics_text):
    """Gọi AI – chỉ đổi model khi hết token"""

    global CURRENT_MODEL

    system_prompt = "Bạn là chuyên gia ngôn ngữ. Nhiệm vụ: Trích xuất tên riêng, tiếng Anh và từ phiên âm."

    user_prompt = f"""Phân tích đoạn lyrics dưới đây và trích xuất từ vựng vào JSON.

MỤC TIÊU: Tập trung vào:
- Tiếng Anh & Slang
- Phiên âm tiếng nước ngoài
- Tên riêng

CẤU TRÚC JSON:
1. "eng"
2. "nuoc_ngoai_phien_am"
3. "ten_rieng"

Lyrics:
---------------------
{lyrics_text}
---------------------
"""

    try:
        chat_completion = client.chat.completions.create(
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt}
            ],
            model=CURRENT_MODEL,
            temperature=0.2,
            response_format={"type": "json_object"}
        )
        return json.loads(chat_completion.choices[0].message.content)

    except Exception as e:
        err = str(e).lower()

        # === CHỈ SWITCH KHI HẾT TOKEN / RATE LIMIT ===
        if any(k in err for k in ["rate", "quota", "token", "limit"]):
            switch_model()
            return "RETRY_WITH_NEW_MODEL"

        print(f"\n[LỖI API KHÁC] {e}")
        return None

def main():

    if not os.path.exists(INPUT_FILE_PATH):
        print("[LỖI] Không tìm thấy file input")
        return

    try:
        df = pd.read_csv(INPUT_FILE_PATH, encoding="utf-8")
    except:
        df = pd.read_csv(INPUT_FILE_PATH, encoding="utf-16")

    df.columns = df.columns.str.strip().str.lower()
    target_col = next((c for c in df.columns if "lyrics" in c or "content" in c), None)

    if not target_col:
        print("[LỖI] Không tìm thấy cột lyrics")
        return

    total_rows = len(df)

    start_row = 0
    if os.path.exists(OUTPUT_FILE_PATH):
        with open(OUTPUT_FILE_PATH, "r", encoding="utf-8-sig") as f:
            start_row = max(0, sum(1 for _ in f) - 1)

    print(f"[*] Start từ dòng {start_row}/{total_rows}")
    print(f"[*] Model ban đầu: {CURRENT_MODEL}")

    with open(OUTPUT_FILE_PATH, "a", encoding="utf-8-sig", newline="") as f:
        fieldnames = ["index_goc", "lyrics", "eng", "nuoc_ngoai_phien_am", "ten_rieng"]
        writer = csv.DictWriter(f, fieldnames=fieldnames)

        if start_row == 0:
            writer.writeheader()

        for i in range(start_row, total_rows):
            lyrics_text = str(df.iloc[i][target_col])

            print(f"\n[*] Dòng {i}/{total_rows} | MODEL: {CURRENT_MODEL}")

            if len(lyrics_text) < 3 or lyrics_text.lower() == "nan":
                writer.writerow({
                    "index_goc": i,
                    "lyrics": "SKIP",
                    "eng": "",
                    "nuoc_ngoai_phien_am": "",
                    "ten_rieng": ""
                })
                continue

            while True:
                res = ask_llama_label(lyrics_text)

                if res == "RETRY_WITH_NEW_MODEL":
                    time.sleep(2)
                    continue
                break

            if res:
                writer.writerow({
                    "index_goc": i,
                    "lyrics": lyrics_text,
                    "eng": res.get("eng", ""),
                    "nuoc_ngoai_phien_am": res.get("nuoc_ngoai_phien_am", ""),
                    "ten_rieng": res.get("ten_rieng", "")
                })
                f.flush()
            else:
                writer.writerow({
                    "index_goc": i,
                    "lyrics": lyrics_text,
                    "eng": "",
                    "nuoc_ngoai_phien_am": "",
                    "ten_rieng": ""
                })

            time.sleep(2)

    print("\n=== HOÀN THÀNH ===")

if __name__ == "__main__":
    main()
# Out:
# [*] Start từ dòng 4802/5253
# [*] Model ban đầu: llama-3.1-8b-instant
#
# [*] Dòng 4802/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4803/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4804/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4805/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4806/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4807/5253 | MODEL: llama-3.1-8b-instant
#
# [⚠️ SWITCH MODEL] → llama-3.3-70b-versatile
#
# [*] Dòng 4808/5253 | MODEL: llama-3.3-70b-versatile
#
# [*] Dòng 4809/5253 | MODEL: llama-3.3-70b-versatile
#
# [*] Dòng 4810/5253 | MODEL: llama-3.3-70b-versatile
#
# [*] Dòng 4811/5253 | MODEL: llama-3.3-70b-versatile
#
# [⚠️ SWITCH MODEL] → openai/gpt-oss-120b
#
# [*] Dòng 4812/5253 | MODEL: openai/gpt-oss-120b
#
# [*] Dòng 4813/5253 | MODEL: openai/gpt-oss-120b
#
# [*] Dòng 4814/5253 | MODEL: openai/gpt-oss-120b
#
# [*] Dòng 4815/5253 | MODEL: openai/gpt-oss-120b
#
# [⚠️ SWITCH MODEL] → openai/gpt-oss-20b
#
# [*] Dòng 4816/5253 | MODEL: openai/gpt-oss-20b
#
# [⚠️ SWITCH MODEL] → meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4817/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4818/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4819/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4820/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4821/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4822/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4823/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4824/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4825/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4826/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4827/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4828/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4829/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4830/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4831/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4832/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4833/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4834/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4835/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4836/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4837/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [⚠️ SWITCH MODEL] → meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4838/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4839/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4840/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4841/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4842/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4843/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4844/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4845/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4846/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4847/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4848/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4849/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4850/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4851/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4852/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4853/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4854/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4855/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4856/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4857/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4858/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4859/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [⚠️ SWITCH MODEL] → qwen/qwen3-32b
#
# [*] Dòng 4860/5253 | MODEL: qwen/qwen3-32b
#
# [*] Dòng 4861/5253 | MODEL: qwen/qwen3-32b
#
# [*] Dòng 4862/5253 | MODEL: qwen/qwen3-32b
#
# [*] Dòng 4863/5253 | MODEL: qwen/qwen3-32b
#
# [*] Dòng 4864/5253 | MODEL: qwen/qwen3-32b
#
# [*] Dòng 4865/5253 | MODEL: qwen/qwen3-32b
#
# [*] Dòng 4866/5253 | MODEL: qwen/qwen3-32b
#
# [*] Dòng 4867/5253 | MODEL: qwen/qwen3-32b
#
# [*] Dòng 4868/5253 | MODEL: qwen/qwen3-32b
#
# [*] Dòng 4869/5253 | MODEL: qwen/qwen3-32b
#
# [*] Dòng 4870/5253 | MODEL: qwen/qwen3-32b
#
# [*] Dòng 4871/5253 | MODEL: qwen/qwen3-32b
#
# [⚠️ SWITCH MODEL] → llama-3.1-8b-instant
#
# [*] Dòng 4872/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4873/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4874/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4875/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4876/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4877/5253 | MODEL: llama-3.1-8b-instant
#
# [⚠️ SWITCH MODEL] → llama-3.3-70b-versatile
#
# [*] Dòng 4878/5253 | MODEL: llama-3.3-70b-versatile
#
# [⚠️ SWITCH MODEL] → openai/gpt-oss-120b
#
# [⚠️ SWITCH MODEL] → openai/gpt-oss-20b
#
# [⚠️ SWITCH MODEL] → meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4879/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [⚠️ SWITCH MODEL] → meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4880/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [⚠️ SWITCH MODEL] → qwen/qwen3-32b
#
# [⚠️ SWITCH MODEL] → llama-3.1-8b-instant
#
# [*] Dòng 4881/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4882/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4883/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4884/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4885/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4886/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4887/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4888/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4889/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4890/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4891/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4892/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4893/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4894/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4895/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4896/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4897/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4898/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4899/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4900/5253 | MODEL: llama-3.1-8b-instant
#
# [⚠️ SWITCH MODEL] → llama-3.3-70b-versatile
#
# [⚠️ SWITCH MODEL] → openai/gpt-oss-120b
#
# [*] Dòng 4901/5253 | MODEL: openai/gpt-oss-120b
#
# [*] Dòng 4902/5253 | MODEL: openai/gpt-oss-120b
#
# [⚠️ SWITCH MODEL] → openai/gpt-oss-20b
#
# [*] Dòng 4903/5253 | MODEL: openai/gpt-oss-20b
#
# [⚠️ SWITCH MODEL] → meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4904/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [⚠️ SWITCH MODEL] → meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4905/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [⚠️ SWITCH MODEL] → qwen/qwen3-32b
#
# [*] Dòng 4906/5253 | MODEL: qwen/qwen3-32b
#
# [⚠️ SWITCH MODEL] → llama-3.1-8b-instant
#
# [*] Dòng 4907/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4908/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4909/5253 | MODEL: llama-3.1-8b-instant
#
# [⚠️ SWITCH MODEL] → llama-3.3-70b-versatile
#
# [⚠️ SWITCH MODEL] → openai/gpt-oss-120b
#
# [⚠️ SWITCH MODEL] → openai/gpt-oss-20b
#
# [⚠️ SWITCH MODEL] → meta-llama/llama-4-maverick-17b-128e-instruct
#
# [⚠️ SWITCH MODEL] → meta-llama/llama-4-scout-17b-16e-instruct
#
# [⚠️ SWITCH MODEL] → qwen/qwen3-32b
#
# [*] Dòng 4910/5253 | MODEL: qwen/qwen3-32b
#
# [*] Dòng 4911/5253 | MODEL: qwen/qwen3-32b
#
# [*] Dòng 4912/5253 | MODEL: qwen/qwen3-32b
#
# [⚠️ SWITCH MODEL] → llama-3.1-8b-instant
#
# [*] Dòng 4913/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4914/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4915/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4916/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4917/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4918/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4919/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4920/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4921/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4922/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4923/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4924/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4925/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4926/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4927/5253 | MODEL: llama-3.1-8b-instant
#
# [⚠️ SWITCH MODEL] → llama-3.3-70b-versatile
#
# [*] Dòng 4928/5253 | MODEL: llama-3.3-70b-versatile
#
# [⚠️ SWITCH MODEL] → openai/gpt-oss-120b
#
# [*] Dòng 4929/5253 | MODEL: openai/gpt-oss-120b
#
# [⚠️ SWITCH MODEL] → openai/gpt-oss-20b
#
# [*] Dòng 4930/5253 | MODEL: openai/gpt-oss-20b
#
# [⚠️ SWITCH MODEL] → meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4931/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4932/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [⚠️ SWITCH MODEL] → meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4933/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4934/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [⚠️ SWITCH MODEL] → qwen/qwen3-32b
#
# [*] Dòng 4935/5253 | MODEL: qwen/qwen3-32b
#
# [⚠️ SWITCH MODEL] → llama-3.1-8b-instant
#
# [*] Dòng 4936/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4937/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4938/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4939/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4940/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4941/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4942/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4943/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4944/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4945/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4946/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4947/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4948/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4949/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4950/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4951/5253 | MODEL: llama-3.1-8b-instant
#
# [⚠️ SWITCH MODEL] → llama-3.3-70b-versatile
#
# [⚠️ SWITCH MODEL] → openai/gpt-oss-120b
#
# [⚠️ SWITCH MODEL] → openai/gpt-oss-20b
#
# [⚠️ SWITCH MODEL] → meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4952/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [⚠️ SWITCH MODEL] → meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4953/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [⚠️ SWITCH MODEL] → qwen/qwen3-32b
#
# [*] Dòng 4954/5253 | MODEL: qwen/qwen3-32b
#
# [⚠️ SWITCH MODEL] → llama-3.1-8b-instant
#
# [*] Dòng 4955/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4956/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4957/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4958/5253 | MODEL: llama-3.1-8b-instant
#
# [⚠️ SWITCH MODEL] → llama-3.3-70b-versatile
#
# [⚠️ SWITCH MODEL] → openai/gpt-oss-120b
#
# [*] Dòng 4959/5253 | MODEL: openai/gpt-oss-120b
#
# [⚠️ SWITCH MODEL] → openai/gpt-oss-20b
#
# [⚠️ SWITCH MODEL] → meta-llama/llama-4-maverick-17b-128e-instruct
#
# [⚠️ SWITCH MODEL] → meta-llama/llama-4-scout-17b-16e-instruct
#
# [⚠️ SWITCH MODEL] → qwen/qwen3-32b
#
# [*] Dòng 4960/5253 | MODEL: qwen/qwen3-32b
#
# [*] Dòng 4961/5253 | MODEL: qwen/qwen3-32b
#
# [⚠️ SWITCH MODEL] → llama-3.1-8b-instant
#
# [*] Dòng 4962/5253 | MODEL: llama-3.1-8b-instant
#
# [⚠️ SWITCH MODEL] → llama-3.3-70b-versatile
#
# [*] Dòng 4963/5253 | MODEL: llama-3.3-70b-versatile
#
# [⚠️ SWITCH MODEL] → openai/gpt-oss-120b
#
# [*] Dòng 4964/5253 | MODEL: openai/gpt-oss-120b
#
# [⚠️ SWITCH MODEL] → openai/gpt-oss-20b
#
# [*] Dòng 4965/5253 | MODEL: openai/gpt-oss-20b
#
# [⚠️ SWITCH MODEL] → meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4966/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [*] Dòng 4967/5253 | MODEL: meta-llama/llama-4-maverick-17b-128e-instruct
#
# [⚠️ SWITCH MODEL] → meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4968/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [*] Dòng 4969/5253 | MODEL: meta-llama/llama-4-scout-17b-16e-instruct
#
# [⚠️ SWITCH MODEL] → qwen/qwen3-32b
#
# [*] Dòng 4970/5253 | MODEL: qwen/qwen3-32b
#
# [*] Dòng 4971/5253 | MODEL: qwen/qwen3-32b
#
# [*] Dòng 4972/5253 | MODEL: qwen/qwen3-32b
#
# [*] Dòng 4973/5253 | MODEL: qwen/qwen3-32b
#
# [⚠️ SWITCH MODEL] → llama-3.1-8b-instant
#
# [*] Dòng 4974/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4975/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4976/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4977/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4978/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4979/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4980/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4981/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4982/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4983/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4984/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4985/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 4986/5253 | MODEL: llama-3.1-8b-instant
#
# [*] Dòng 